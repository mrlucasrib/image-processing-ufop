% %% [markdown]
% # Lucas Moreira 20.1.4972
% ### Questão 1

% %%
x = [1 2 3 4 5 6]
% Out:
% x =
%
%    1   2   3   4   5   6

% %%
x(5)
% Out:
% ans =  5

% %%
x(2 : 5)
% Out:
% ans =
%
%    2   3   4   5

% %%
x(1 : end)
% Out:
% ans =
%
%    1   2   3   4   5   6

% %%
x(1 : end - 1)
% Out:
% ans =
%
%    1   2   3   4   5

% %%
x(6 : -2 : 1)
% Out:
% ans =
%
%    6   4   2

% %%
x([1 5 2 1 1])
% Out:
% ans =
%
%    1   5   2   1   1

% %% [markdown]
% ### Questão 2

% %%
M = [1 2 10 1; 1 5 1 1; 1 4 8 1; 1 10 3 1]
% Out:
% M =
%
%     1    2   10    1
%     1    5    1    1
%     1    4    8    1
%     1   10    3    1

% %% [markdown]
% ### Questão 3

% %%
A = [1 2 3]
B = [3 2 1]
M = [4 5 6 ; 6 5 3]
% Out:
% A =
%
%    1   2   3
%
% B =
%
%    3   2   1
%
% M =
%
%    4   5   6
%    6   5   3

% %%
# a) soma vetores
A + B
% Out:
% ans =
%
%    4   4   4

% %%
# b) soma de vetor com matriz
A + M
% Out:
% ans =
%
%    5   7   9
%    7   7   6

% %%
# c) Soma da transposta de a com B
A'+ B
% Out:
% ans =
%
%    4   3   2
%    5   4   3
%    6   5   4

% %%
# d) Sutralçao da matriz M com a matriz gerada pelos vetores A e B
M - [A; B]
% Out:
% ans =
%
%    3   3   3
%    3   3   2

% %%
# e) Tentativa falha de criar uma matriz com o vetor A e a transposta de B
[A; B']
% Out:
% error: vertical dimensions mismatch (1x3 vs 3x1)

% %%
# f) Criação de uma matriz com os vetores A e B
[A; B]
% Out:
% ans =
%
%    1   2   3
%    3   2   1

% %%
# g) Subtrai 3 do valor presente em cada posição do vetor
M - 3
% Out:
% ans =
%
%    1   2   3
%    3   2   0

% %%
# h) Erro pois tenta mutiplicar como uma matriz e para isso a a quantidade de colunas da primeira tem que ser igual a quantidade de linhas da outra
A * B
% Out:
% error: operator *: nonconformant arguments (op1 is 1x3, op2 is 1x3)

% %%
# i) Multiplicação ponto a ponto de A com B
A.* B
% Out:
% ans =
%
%    3   4   3

% %% [markdown]
% ### Questão 4

% %%
MATRIZ = [2 10 7 6;
        3 12 25 9]
# a)
COM_NOVA_COLUNA = [MATRIZ; 30 21 19 1]
% Out:
% MATRIZ =
%
%     2   10    7    6
%     3   12   25    9
%
% COM_NOVA_COLUNA =
%
%     2   10    7    6
%     3   12   25    9
%    30   21   19    1

% %%
# b)
B = [COM_NOVA_COLUNA(1:3,:) COM_NOVA_COLUNA(:,2) COM_NOVA_COLUNA(:,4)]
% Out:
% B =
%
%     2   10    7    6   10    6
%     3   12   25    9   12    9
%    30   21   19    1   21    1

% %% [markdown]
% ### Questão 5

% %%
VETOR = 31:2:75
% Out:
% VETOR =
%
%  Columns 1 through 16:
%
%    31   33   35   37   39   41   43   45   47   49   51   53   55   57   59   61
%
%  Columns 17 through 23:
%
%    63   65   67   69   71   73   75

% %%
V_RAND = rand(100,1,10)
% Out:
% V_RAND =
%
% ans(:,:,1) =
%
%    0.615330
%    0.045411
%    0.989320
%    0.681710
%    0.485934
%    0.459475
%    0.450691
%    0.631383
%    0.377935
%    0.207080
%    0.814260
%    0.471744
%    0.211062
%    0.623665
%    0.948019
%    0.600129
%    0.145250
%    0.672561
%    0.025588
%    0.621948
%    0.147272
%    0.565027
%    0.511486
%    0.744025
%    0.049918
%    0.827822
%    0.399495
%    0.651226
%    0.119009
%    0.312696
%    0.012601
%    0.051617
%    0.516042
%    0.492870
%    0.859689
%    0.795113
%    0.846751
%    0.445479
%    0.483353
%    0.626519
%    0.772744
%    0.382930
%    0.487569
%    0.451370
%    0.556455
%    0.699883
%    0.309141
%    0.646592
%    0.120835
%    0.098459
%    0.500591
%    0.403617
%    0.173498
%    0.555611
%    0.318106
%    0.054509
%    0.916264
%    0.862995
%    0.826976
%    0.371756
%    0.158397
%    0.149152
%    0.778647
%    0.210017
%    0.717295
%    0.890645
%    0.766701
%    0.738303
%    0.048033
% ...

% %%
max(V_RAND)
% Out:
% ans =
%
% ans(:,:,1) =  0.98932
% ans(:,:,2) =  0.98948
% ans(:,:,3) =  0.99432
% ans(:,:,4) =  0.98094
% ans(:,:,5) =  0.99175
% ans(:,:,6) =  0.98323
% ans(:,:,7) =  0.99522
% ans(:,:,8) =  0.99920
% ans(:,:,9) =  0.98725
% ans(:,:,10) =  0.99658
